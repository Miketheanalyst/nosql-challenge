# %% [markdown]
# # Eat Safe, Love (NoSQL_setup_starter.ipynb)

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with `YOUR IMPORT TEXT HERE`

# %%
#15

# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
#16

# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# List all databases to confirm our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'restaurant_db', 'uk_food']

# %%
#18
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
#19
# review the collections in our new database
# List all collections in the 'uk_food' database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# Review a document in the establishments collection
document = db.establishments.find_one()
pprint(document)
# Out:
# {'AddressLine1': 'The Leas',
#  'AddressLine2': 'Kingsdown',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Walmer and Kingsdown Golf Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4587.793855801259,
#  'FHRSID': 452092,
#  'LocalAuthorityBusinessID': 'PI/000040614',
#  'LocalAuthorityCode': '182',
#  'LocalAuthorityEmailAddress': 'publicprotection@dover.gov.uk',
#  'LocalAuthorityName': 'Dover',
#  'LocalAuthorityWebSite': 'http://www.dover.gov.uk/',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT14 8EP',
#  'RatingDate': '2019-09-10T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': '5',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6675eb7655efe2f4a0092a9e'),
#  'geocode': {'latitude': '51.1787300109863', 'longitude': '1.40325689315796'},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/452092',
# ...

# %%
#22

# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant={
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restaurant)
# Out:
# InsertOneResult(ObjectId('6678db310410e88102a8f87d'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
query={"BusinessName":"Penang Flavours"}

results=establishments.find(query)

for res in results:
    pprint(res)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6678db310410e88102a8f87d'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query={"BusinessType": "Restaurant/Cafe/Canteen"} 
fields={"BusinessTypeID": 1, "BusinessType": 1}

results=establishments.find(query,fields)

for res in results:
    pprint(res)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6675eb7655efe2f4a0092aa0')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6675eb7655efe2f4a0092aa2')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6675eb7655efe2f4a0092aa4')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6675eb7655efe2f4a0092aa5')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6675eb7655efe2f4a0092aa7')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6675eb7655efe2f4a0092aa8')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6675eb7655efe2f4a0092aab')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  '_id': ObjectId('6675eb7655efe2f4a0092ab3')}
# {'BusinessType': 'Restaurant/Cafe/Canteen',
# ...

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Cell #27
# Assign a sample BusinessTypeID for demonstration purposes
business_type_id = 12345  # Assuming a sample BusinessTypeID

# Update the new restaurant with the correct BusinessTypeID
update_result = collection.update_one(
    {"BusinessName": "Penang Flavours"},
    {"$set": {"BusinessTypeID": business_type_id}}
)

print("Matched documents:", update_result.matched_count)
print("Modified documents:", update_result.modified_count)
# Out:
# Matched documents: 1
# Modified documents: 1

# %%
# Cell #28
# Confirm that the new restaurant was updated
updated_restaurant = collection.find_one({"BusinessName": "Penang Flavours"})
print(updated_restaurant)
# Out:
# {'_id': ObjectId('6678cf484b50d1ab54a4e57e'), 'BusinessName': 'Penang Flavours', 'BusinessType': 'Restaurant/Cafe/Canteen', 'AddressLine1': '123 High Street', 'AddressLine2': '', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'SE10 9XY', 'LocalAuthorityName': 'Greenwich', 'Latitude': '51.4828', 'Longitude': '0.0077', 'RatingValue': '5', 'RatingKey': 'fhrsid', 'BusinessTypeID': 12345}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Cell #29
# Delete all documents where LocalAuthorityName is "Dover Local Authority"
delete_result = collection.delete_many({"LocalAuthorityName": "Dover Local Authority"})
print("Deleted documents:", delete_result.deleted_count)
# Out:
# Deleted documents: 0

# %%
# Cell #30
# Count documents before deletion
count_before = collection.count_documents({})
print("Document count before deletion:", count_before)
# Out:
# Document count before deletion: 3

# %%
# Cell #31
# Delete documents where LocalAuthorityName is "Dover Local Authority"
delete_result = collection.delete_many({"LocalAuthorityName": "Dover Local Authority"})
print("Deleted documents:", delete_result.deleted_count)
# Out:
# Deleted documents: 0

# %%
# Cell #32
# Count documents after deletion
count_after = collection.count_documents({})
print("Document count after deletion:", count_after)
# Out:
# Document count after deletion: 3

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Cell #33
# Convert latitude and longitude fields from strings to decimal numbers and RatingValue to integers
update_result = collection.update_many(
    {},
    [
        {"$set": {
            "Latitude": {"$toDouble": "$Latitude"},
            "Longitude": {"$toDouble": "$Longitude"},
            "RatingValue": {"$toInt": "$RatingValue"}
        }}
    ]
)
print("Matched documents:", update_result.matched_count)
print("Modified documents:", update_result.modified_count)
# Out:
# Matched documents: 3
# Modified documents: 3

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
#34

# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 4138, 'nModified': 4138, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Cell #35
# Change the data type from String to Integer for RatingValue and verify the conversion
update_result = collection.update_many(
    {},
    [
        {"$set": {
            "RatingValue": {"$toInt": "$RatingValue"}
        }}
    ]
)
print("Matched documents:", update_result.matched_count)
print("Modified documents:", update_result.modified_count)

# Verify the conversion
sample_documents = collection.find({}, {"_id": 0, "RatingValue": 1}).limit(5)
for doc in sample_documents:
    print(doc)
# Out:
# Matched documents: 3
# Modified documents: 0
# {'RatingValue': 5}
# {'RatingValue': 5}
# {'RatingValue': 5}

# %%
# Cell #36
# Check the RatingValue for establishments in London
sample_documents_london = collection.find({"LocalAuthorityName": {"$regex": "London"}}, {"_id": 0, "RatingValue": 1}).limit(5)
for doc in sample_documents_london:
    print(doc)
